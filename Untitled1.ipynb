# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Skripsi/Program Skripsi/Hasil/labellingfix.csv')
data
# Out:
#                                               text asli  \
# 0     aplikasinya ringan fitur reksa dananya lengkap...
# 1     umum sistem aplikasi digunakan aplikasi standa...
# 2     bareksa aplikasi investasi bagus ringan jelas ...
# 3     mau menambahkan rekening tersebut terus ditola...
# 4     performa tampilan aplikasi sangat bagus ringan...
# ...                                                 ...
# 2002  upload bukti transaksi tertunda terus gagal pe...
# 2003  melakukan penarikan tanggal september kemarin ...
# 2004      transaksi lambat banget aplikasi kurang bagus
# 2005  mohon maaf kebetulan ektp buram bisa terbaca k...
# 2006   mohon diperbaiki lebih lanjut edit profil update
#
#                                             text_prepro  compound scores  \
# 0     aplikasi ringan fitur reksa dana lengkap cocok...               16
# 1     umum sistem aplikasi guna aplikasi standard mi...              -11
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membaca dataset
data = pd.read_csv('/content/drive/MyDrive/Skripsi/Program Skripsi/Hasil/labellingfix.csv')

# Pastikan kolom 'Sentimen' digunakan untuk perbandingan
label_counts = data['Sentimen'].value_counts()

# Menampilkan perbandingan jumlah label
print("Jumlah masing-masing label:")
print(label_counts)

# Membuat visualisasi perbandingan label
plt.figure(figsize=(8, 6))
label_counts.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Perbandingan Label Positif dan Negatif', fontsize=14)
plt.xlabel('Sentimen', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Jumlah masing-masing label:
# Sentimen
# Positif    1210
# Negatif     797
# Name: count, dtype: int64

# %%
import pandas as pd

# Membaca dataset
data = pd.read_csv('/content/drive/MyDrive/Skripsi/Program Skripsi/Hasil/labellingfix.csv')

# Memisahkan data positif dan negatif
data_positif = data[data['Sentimen'] == 'Positif']
data_negatif = data[data['Sentimen'] == 'Negatif']

# Mengambil 5 nilai tertinggi untuk label positif
top_positif = data_positif.nlargest(5, 'compound scores')

# Mengambil 5 nilai terendah untuk label negatif
top_negatif = data_negatif.nsmallest(5, 'compound scores')

# %%
# Menampilkan hasil
print("5 Positif Tertinggi:")
top_positif[['text asli', 'compound scores', 'Sentimen']]
# Out:
# 5 Positif Tertinggi:
#                                               text asli  compound scores  \
# 430   memiliki platform aplikasi reksa dana bareksa ...               56
# 548   aplikasi bagus cocok yang investasi reksa dana...               56
# 852   alhamdulillah tim bareksa merespon pembelian e...               49
# 183   bareksa aplikasinya cukup bagus produk reksa d...               48
# 1257  beli reksa dana campuran harga lebih murahlalu...               43
#
#      Sentimen
# 430   Positif
# 548   Positif
# 852   Positif
# 183   Positif
# 1257  Positif

# %%
print("\n5 Negatif Tertinggi:")
top_negatif[['text asli', 'compound scores', 'Sentimen']]
# Out:
# 5 Negatif Tertinggi:
#                                               text asli  compound scores  \
# 95    aplikasi kurang paham susah ribet datanya send...              -47
# 498   sudah investasi berhasil aplikasinya sudah men...              -47
# 109   ingin mendaftar bareksa memasukkan nomor reken...              -43
# 1083  lama cek ovo tiba tiba asetnya dilimpahkan bar...              -40
# 196   bagaimana cara mengetahui itu bagus padahal pe...              -37
#
#      Sentimen
# 95    Negatif
# 498   Negatif
# 109   Negatif
# 1083  Negatif
# 196   Negatif

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membaca dataset
data = pd.read_csv('/content/drive/MyDrive/Skripsi/Program Skripsi/Hasil/labellingfix.csv')

# Pastikan kolom 'Sentimen' digunakan untuk perbandingan
label_counts = data['Sentimen'].value_counts()

# Menampilkan perbandingan jumlah label
print("Jumlah masing-masing label:")
print(label_counts)

# Membuat visualisasi perbandingan label
plt.figure(figsize=(8, 6))
label_counts.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Perbandingan Label Positif dan Negatif', fontsize=14)
plt.xlabel('Sentimen', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Memisahkan data positif dan negatif
data_positif = data[data['Sentimen'] == 'Positif']
data_negatif = data[data['Sentimen'] == 'Negatif']

# Mengambil 5 nilai tertinggi untuk label positif
top_positif = data_positif.nlargest(5, 'compound scores')

# Mengambil 5 nilai terendah untuk label negatif
top_negatif = data_negatif.nsmallest(5, 'compound scores')

# Menampilkan hasil
print("5 Positif Tertinggi:")
print(top_positif[['text asli', 'compound scores', 'Sentimen']])

print("\n5 Negatif Tertinggi:")
print(top_negatif[['text asli', 'compound scores', 'Sentimen']])

# Membuat visualisasi 5 positif tertinggi
plt.figure(figsize=(10, 6))
plt.barh(top_positif['text asli'], top_positif['compound scores'], color='green')
plt.title('5 Positif Tertinggi berdasarkan Compound Scores', fontsize=14)
plt.xlabel('Compound Scores', fontsize=12)
plt.ylabel('Text Asli', fontsize=12)
plt.gca().invert_yaxis()
plt.show()

# Membuat visualisasi 5 negatif tertinggi
plt.figure(figsize=(10, 6))
plt.barh(top_negatif['text asli'], top_negatif['compound scores'], color='red')
plt.title('5 Negatif Tertinggi berdasarkan Compound Scores', fontsize=14)
plt.xlabel('Compound Scores', fontsize=12)
plt.ylabel('Text Asli', fontsize=12)
plt.gca().invert_yaxis()
plt.show()
# Out:
# Jumlah masing-masing label:
# Sentimen
# Positif    1210
# Negatif     797
# Name: count, dtype: int64
# 5 Positif Tertinggi:
#                                               text asli  compound scores  \
# 430   memiliki platform aplikasi reksa dana bareksa ...               56
# 548   aplikasi bagus cocok yang investasi reksa dana...               56
# 852   alhamdulillah tim bareksa merespon pembelian e...               49
# 183   bareksa aplikasinya cukup bagus produk reksa d...               48
# 1257  beli reksa dana campuran harga lebih murahlalu...               43
#
#      Sentimen
# 430   Positif
# 548   Positif
# 852   Positif
# 183   Positif
# 1257  Positif
#
# 5 Negatif Tertinggi:
#                                               text asli  compound scores  \
# 95    aplikasi kurang paham susah ribet datanya send...              -47
# 498   sudah investasi berhasil aplikasinya sudah men...              -47
# ...

# %%
# Membuat WordCloud untuk teks positif
text_positif = ' '.join(data_positif['text_prepro'].astype(str))
wordcloud_positif = WordCloud(width=800, height=400, background_color='white', colormap='Greens').generate(text_positif)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_positif, interpolation='bilinear')
plt.title('WordCloud untuk Sentimen Positif', fontsize=14)
plt.axis('off')
plt.show()

# %%
# Membuat WordCloud untuk teks negatif
text_negatif = ' '.join(data_negatif['text_prepro'].astype(str))
wordcloud_negatif = WordCloud(width=800, height=400, background_color='white', colormap='Reds').generate(text_negatif)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_negatif, interpolation='bilinear')
plt.title('WordCloud untuk Sentimen Negatif', fontsize=14)
plt.axis('off')
plt.show()

# %%
import pandas as pd
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Membaca dataset
data = pd.read_csv('/content/drive/MyDrive/Skripsi/Program Skripsi/Hasil/labellingfix.csv')

# Memisahkan data positif dan negatif
data_positif = data[data['Sentimen'] == 'Positif']
data_negatif = data[data['Sentimen'] == 'Negatif']

# Menggabungkan teks untuk masing-masing sentimen
text_positif = ' '.join(data_positif['text_prepro'].astype(str))
text_negatif = ' '.join(data_negatif['text_prepro'].astype(str))

# Tokenisasi dan menghitung frekuensi kata
frekuensi_positif = Counter(text_positif.split())
frekuensi_negatif = Counter(text_negatif.split())

# Menampilkan 10 kata paling sering muncul di masing-masing label
print("10 Kata Paling Sering Muncul di Label Positif:")
print(frekuensi_positif.most_common(10))

print("\n10 Kata Paling Sering Muncul di Label Negatif:")
print(frekuensi_negatif.most_common(10))

# Visualisasi WordCloud untuk kata-kata paling sering muncul
def buat_wordcloud(frekuensi, title, colormap):
    wordcloud = WordCloud(width=800, height=400, background_color='white', colormap=colormap).generate_from_frequencies(frekuensi)
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title, fontsize=14)
    plt.axis('off')
    plt.show()

buat_wordcloud(frekuensi_positif, 'WordCloud Kata Terpopuler - Positif', 'Greens')
buat_wordcloud(frekuensi_negatif, 'WordCloud Kata Terpopuler - Negatif', 'Reds')
# Out:
# 10 Kata Paling Sering Muncul di Label Positif:
# [('aplikasi', 594), ('bareksa', 461), ('dana', 443), ('reksa', 340), ('beli', 337), ('investasi', 310), ('lebih', 306), ('baik', 296), ('mudah', 282), ('bisa', 268)]
#
# 10 Kata Paling Sering Muncul di Label Negatif:
# [('aplikasi', 560), ('tidak', 315), ('bareksa', 237), ('masuk', 212), ('bisa', 202), ('saya', 192), ('lama', 189), ('padahal', 174), ('hari', 170), ('daftar', 169)]
